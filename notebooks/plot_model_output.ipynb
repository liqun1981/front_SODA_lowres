# %%
# Description: Plot front_relax_MSA output
#           -Final T, S, and V
#           -Difference between inital and final state variables
#           -

# %%
# Import packagaes
import xmitgcm
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set path to model output
path_data = '/work/Marion.Alberty/front_SODA_lowres/run_test5'
# Open dataset with xmitgcm
ds0 = xmitgcm.open_mdsdataset(path_data,iters=[0],geometry='cartesian')
dsN = xmitgcm.open_mdsdataset(path_data,iters=[3600],geometry='cartesian')

# %%
# ds0

# %%
# Plot initial sea surface height
ds0.Eta.plot()

# %%
# Plot final sea surface height
dsN.Eta.plot()

# %%
# Plot salinity
Ssurf0 = ds0.S.isel(Z = 0)
Ssurf0.plot()

# %%
# Plot temperature
Ssurf0 = ds0.T.isel(Z = 0)
Ssurf0.plot()

# %%
# Plot along front velocity
Ssurf0 = ds0.U.isel(XG = 10)
Ssurf0.plot()

# %%
# Plot vertical velocity
Ssurf0 = dsN.W.isel(XC = 10)
Ssurf0.plot()
